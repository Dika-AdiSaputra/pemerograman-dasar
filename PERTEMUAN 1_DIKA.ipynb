# %%
# Biodata diri

nama = "DIKA"
umur = 20
jurusan = "TRPE"
semester = 3
matakuliah = 'pemerograman dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# DIKA
# 20
# TRPE
# 3
# pemerograman dasar
# False
